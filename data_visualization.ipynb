# %%
##### Data Visualization Notes #####

# %%
### Notes

# Good to use different hues to see sub groups
# Create subplots with col and row
# point transparency good when have lots of points that over lap (darker = more points in that area)

# for comparing groups = categorical plots (count and bar)
# comparisions between groups = box

# line plots have both quantitative x and y, point plots have one categorical
# use bar plot when want to show sum or count of a group, use point plot when want to show mean or median of a group

# Palette options:
# sequential for data that has a natural order (light to dark)
# diverging for data that has a natural midpoint (light to dark on either side)
# create custom palette with a list of colours (can use hex codes)

# time data - line plot

# for time series with two or mroe variables that do not share the same scale, use twin axes and can also colour coordinate the lines/markers with title colours 

# labels - capitalize as a sentence

# histograms - default number of bins = 10
# use histsahpe = 'step' if overlapping histograms 

# can use a for loop to automate figures from the data, instead of doing it individually for each category in the daa

# %%
### Matplotlib ###

## pyplot

import matplotlib.pyplot as plt

fig, ax = plt.subplots()            # creates empty figureand axis to build plots

ax.plot(data_name['column_name_x'], data_name['column_name_y'])     # creates a line

ax.plot(data_name['column_name_x'], data_name['column_name_y'])     # do again to add another line

plt.show()


## Customizations

# Style - first line of code

plt.style.use('style_name')

# ggplot                        (like R)
# default
# bmh                           (blue and red)
# seaborn-colorblind            (blue and green)
# tableau-colorblind10
# grayscale                     (good for black and white)
# Solarize_Light2               


# Individual Elements

ax.plot(data_name['column_name_x'], data_name['column_name_y'],
        marker = "x",
        linestyle = 'None',
        color = 'b')

# markers

# o     - circles
# v     - triangles pointing downward
# .     - point
# x     - x

# linestyle

# --    - dashed
# None  - no line
# -.    - dash-dot
# :     - dotted

# colour 

# r     - red
# b     - blue
# g     - green
# y     - yellow
# m     - magenta
# c     - cyan
# k     - black


# axes labels and title

ax.set_xlabel('axis label')

ax.set_ylabel('axis label')

ax.set_title('axis label')


# change label colour

ax.set_xlabel('axis label', color = 'blue')


# edit the ticks on the axes

ax.tick_params('y', colors = 'blue')

ax.tick_params('y', colors = 'blue')

## Subplots 

fig, ax = plt.subplots(4,2)         # create empty figure with 4 rows, 2 columns of plots

# now have to index/specify for which plot to add data [row, column]

ax[0,0].plot(data_name['column_name_x'], data_name['column_name_y'])
ax[0,1].plot(data_name['column_name_x'], data_name['column_name_y'])


# get plots to have same y-axis values

fig, ax = plt.subplots(4,2,  sharey = True) 


## Error bars

ax.errorbar(data_name['column_name_x'], data_name['column_name_y'], yerr = data_name['column_name_error'])

# %%
### Time Series with Matplotlib ###

## explore the data and check for DateTimeIndex

data_name.index


## Select time periods (zoom-in)

defined_period = data_name['2000-01-01':'2009-12-31']

fig, ax = plt.subplots()  
ax[0,0].plot(defined_period['column_name_x'], defined_period['column_name_y'])


## Time Series of different variables - may have different scales (use twin axes)

fig, ax = plt.subplots()  
ax[0,0].plot(data_name_1.index, data_name_1['column_name_y'])

# create twin axes
ax2 = ax.twinx()            # will share x axis

ax2.plot(data_name_2.index, data_name_2['column_name_y'])       # start with ax2, unlike just ax before



## function for time-series plot - can add more elements 

def plot_time_series(axes, x, y, color, xlabel, ylabel):
    axes.plot(x,y, color = color)
    axes.set_xlabel(xlabel)
    axes.set_ylabel(ylabel)


## Annotations

ax.annotate("annotation_here", 
            xy = (pd.Timestamp('2026-05-18'), ypositionofinterest),     # specify area ofinterest
            xytext = (pd.Timestamp('2020-05-18'), yposition),           # define position for the text (trial and error to find spot)
            arrowprops = {})                                            # include arrow between text and position of interest

# customizing the arrow (include in {})

# 'arrowstyle" : "->", "color" : "blue"

# %%
### Quant Comparisions with Matplotlib ###

## Bar Charts

fig, ax = plt.subplots()
ax.bar(data_name.index, data_name['column_name_1'], label = 'category_1')     # add label with ax.legend() below to get a legend to show the colour for each category
ax.bar(data_name.index, data_name['column_name_2'], bottom = data_name['column_name_1'], label = "category_2")         # can add additional info by stacking bars - specify additional column and specify where this variable should start (at the end of the original column's bar)
ax.bar(data_name.index, data_name['column_name_3'], bottom = data_name['column_name_1'] + data_name['column_name_2'], label = 'category_3')       # stack additional column, start at the value of column 1 + 2 (so three different colours stacked)
ax.set_xticklabels(data_name.index, rotation = 90)          # can rotate names for each bar sothey do not overlap
ax.set_ylabel('label name')
ax.legend()
plt.show()


# get bars from different data sets

fig, ax = plt.subplots()
ax.bar("name_1", data_name_1['column_name'].mean())         # 'name_1' is the x argument
ax.bar("name_2", data_name_2['column_name'].mean())
plt.show()


# error bars

fig, ax = plt.subplots()
ax.bar("name_1", data_name_1['column_name'].mean(), yerr = data_name_1['column_name'].std())        # yerr = y error, is a vertical marker at the top of the bar
ax.bar("name_2", data_name_2['column_name'].mean(), yerr = data_name_2['column_name'].std())
plt.show()



## Histograms

fig, ax = plt.subplots()
ax.hist(data_name_1['column_name'], label = 'category_1', bins = 15, histtype = 'step')      # specify histtype as step for lines instead of filled shape = easier to see if overlap
ax.hist(data_name_2['column_name'], label = 'category_2', bins = [5,10,15,20,25])            # can speficy a sequence for bins
ax.set_xlabel('label')
ax.set_ylabel('label')
ax.legend()
plt.show()


## Boxplots

fig, ax = plt.subplots()
ax.boxplot([data_name_1['column_name'], data_name_2['column_name']])
ax.set_xticklabels(['name_1', 'name_2'])
ax.set_ylabel('label')
plt.show()


## Scatter plots

fig, ax = plt.subplots()
ax.scatter(data_name["column_name"], data_name["column_name"])
ax.set_xlabel("label")
ax.set_ylabel("label")
plt.show()


# different categories

defined_period_1 = data_name['2000-01-01':'2009-12-31']     # define categories
defined_period_2 = data_name['2010-01-01':'2019-12-31']

fig, ax = plt.subplots()
ax.scatter(defined_period_1["column_name_1"], defined_period_1["column_name_2"], color = 'blue', label = '00s')
ax.scatter(defined_period_2["column_name_1"], defined_period_2["column_name_2"], color = 'green', label = '10s')
ax.set_xlabel("label")
ax.set_ylabel("label")
ax.legend()
plt.show()


# use colour to include info on third vairable - ex: colour of points chaning over time peridods

fig, ax = plt.subplots()
ax.scatter(data_name["column_name"], data_name["column_name"], c = data_name['column_name'])        # c = third variable, such as some denoting dates
ax.set_xlabel("label")
ax.set_ylabel("label")
plt.show()

# %%
### Automate with a For loop ###

# extract the column with teh categories and find the unique values

extracted_column = data_name['column_name']
categories = extracted_column.unique()
print(categories)

# create for loop to interate over all the categories

for category in categories:
    filtered_data_name = data_name[data_name['column_name'] == category]
    ax.bar(category, filtered_data_name['column_of_interest'].mean(),
    yerr = filtered_data_name['column_of_interest'].std())
ax.set_ylabel('label')
ax.ser_xticklabels(categories, rotation = 90)
plt.show()

# %%
### Finsihing and Exporting with MatplotLib ###

fig, ax = plt.subplots()
ax.bar(data_name.index, data_name['column_name'])     
ax.set_xticklabels(data_name.index, rotation = 90)
ax.set_ylabel("label")
plt.show()


# set figure size [width, height]

fig.set_size_inches([4,6])


# pick file type

fig.savefig('name.jpg', 
            quality = 70,       # optional to specify quality 1-100
            dpi = 300)          # optional dots per inch - higher = more dense

# png   - quality, but larger file
# jpg   - more compressed
# svg

# %%
### Steps with Seaborn ###

import seaborn as sns
import matplotlib.pyplot as plt

plt.show()    # show the plot

# choose plot type (scatter, line, bar, point, box, count)

# relational plots (scatter, line) - use relplot() function
sns.relplot(x = "column_name", y = "column_name", data = data_frame_name, kind = "scatter")    # scatter plot

# categorical plots (bar, point, box, count) - use catplot() function
sns.catplot(x = "column_name", y = "column_name", data = data_frame_name, kind = "bar")    # bar plot

# heatmap
sns.heatmap(data_name)
sns.heatmap(data_name.corr(numeric_only = True), annot = True, cmap = 'coolwarm')
sns.heatmap(data_name.isna(), cbar = False)
pivot = data_name.pivot_table(values = 'val', index = 'row', columns = 'col')
sns.heatmap(pivot, annot = True)
counts = data_name.groupby(['A','B']).size().unstack()
sns.heatmap(counts, annot = True)

# pairplots - plots all relationships between variables, distributions on the diagonal
sns.pairplot(data = data_name)
sns.pairplot(data = data_name, vars = ['var_ of_interest_1', 'var_of_interest_2', 'var_of_interest_3'])

# kde - kernel density estimation (specify cumulitive = True for cumulative dist function, prob of duration being less than or equal to x value)
sns.kdeplot(data = data_name, x = 'column_name_1', hue = 'column_name_2', cut = value, cumulative = True)    # specity cut = a value, which is how far past the max and min values to show, ex. sometimes negative values do not make sense given the sacle of the variable



# subgroups

hue = "column name"    # for subgrouping (can be categorical or quantitative)
row = "column name"    # for creating subplots (can be categorical or quantitative)
col = "column name"    # for creating subplots (can be categorical or quantitative)


# customize

sns.set_style()        # set style of plot (background colour and grid lines)
sns.set_palette()      # set colour palette for plot elements
sns.set_context()      # set size of plot

type(plot_object_name)              # check type of plot object (FacetGrid, AxesSubplot, etc.)
g.figure.suptitle("title name")     # add title to FacetGrid object
g.set_title("title name")           # add title to FacetGrid object
g.set_titles("title name")          # add title to each subplot in FacetGrid object

g.set(xlabel = "x axis label", ylabel = "y axis label")    # add axis labels to FacetGrid object
plt.xticks(rotation = 45)                                  # rotate x axis labels by 45 degrees

# %%
### Seaborn Plot ###

## Easy Visualization - built on matplotlib
## Good with pandas

import seaborn as sns
import matplotlib.pyplot as plt


age = [45, 23, 34, 52, 28, 19, 40]
income = [180000, 60000, 120000, 98000,70000, 10000, 90000]
gender = ['M', 'F', 'M', 'F', 'M', 'F', 'M']
country = ['USA', 'Canada', 'USA', 'UK', 'Canada', 'UK', 'USA']
stem = ['yes', 'no', 'yes', 'no', 'yes', 'no', 'yes']

sns.scatterplot(x = age, y = income)
plt.show()

sns.countplot(x = gender)
plt.show()

sns.countplot(y = country)    # specify y to have horizontal bars
plt.show()


## Pandas

# works with tidy data -> each column is a variable, each row is an observation, each cell is a value

import pandas as pd

#sns.countplot(x = "column_name", data = data_frame_name)    # specify data frame to use column from
#plt.show()



## add colour for third variable

sns.scatterplot(x = age, y = income, hue = country, hue_order = ['USA', 'Canada', 'UK'])    # specify order of categories in legend
plt.show()

sns.countplot(x = gender, hue = country)    
plt.show()


# can first define the cololur palette
palette = {'USA': 'blue', 'Canada': 'orange', 'UK': 'green'}
sns.scatterplot(x = age, y = income, hue = country, palette = palette)
plt.show()


## Colour options - can also use hex codes

# 'blue' or 'b'
# 'orange' or 'o'
# 'green' or 'g'
# 'red' or 'r'
# 'magenta' or 'm'
# 'yellow' or 'y'
# 'white' or 'w'
# 'black' or 'k'
# 'cyan' or 'c'



### Relational plots

## Scatter - each point = observation

#relplot() - scatter or line plots, can create subplots in a single figure, need to specify kind = "scatter" or "line"

sns.scatterplot(x = 'column_name', y = 'column_name', data = data_frame_name) 

sns.relplot(x = 'column_name', y = 'column_name', data = data_frame_name, kind = "scatter")   


# col = "column_name"                       - plots in horizontal row

# row = "column_name"                       - plots in vertical column

# row = "column_name", col = "column_name"  - plots in grid

# col_wrap = 2                              - specify how many columns

# col_order = ['category1', 'category2']    - specify order of categories



## Point sizes, style, and transparency

# size = 'column_name'          - specify column to use for point sizes

# hue = 'column_name'           - specify column to use for point colours

# style = 'column_name'         - specify column to use for point styles

# alpha = 0.5                   - specify transparency (0-1, where 0 is transparent and 1 is opaque)



## Line Plots - ex: same variable over time

sns.relplot(x = 'column_name', y = 'column_name', data = data_frame_name, kind = "line")    # specify kind = "line" for line plot

# style = 'column_name'    - specify column to use for line styles (different dashes or solid lines)

# hue = 'column_name'      - specify column to use for line colours

# markers = True           - set markers for each point

# dashes = False           - adjust dashed lines (False for solid lines, or can specify custom dash patterns)  


# if multiple obervations for each x value, will display the mean and confidence interval (shaded area around line)

# errorbar = "sd"          - adjust to show the standard deviation instead of confidence interval

# errorbar = None          - remove confidence interval

# %%
### Categorical and Quantiative Plots ###


## catplot() - same options as relplot (kind = "count" or "bar" or "box" or "point")


## Count Plot - shows count of each category

sns.countplot(x = 'column_name', data = data_frame_name)    

sns.catplot(x = 'column_name', data = data_frame_name, kind = "count")    # specify kind = "count" for count plot

# can create list of the categories to specify their order in the plot
order = ['category1', 'category2', 'category3']
sns.countplot(x = 'column_name', data = data_frame_name, order = order)

# order = list_name    - specify order of categories using list of category names


## Bar plot - shows summary statistic (ex: mean) for each category

sns.catplot(x = 'column_name', y = 'column_name', data = data_frame_name, kind = "bar")    # specify kind = "bar" for bar plot

# shows 95% CI by default

# errorbar = "sd"          - adjust to show the standard deviation instead of confidence interval

# errorbar = None          - remove confidence interval

# switch order of x and y to have horizontal bars instead of vertical bars


## Box Plot - info on median, quartiles, spread/skewness, and outliers

sns.catplot(x = 'column_name', y = 'column_name', data = data_frame_name, kind = "box")    # specify kind = "box" for box plot

# can change order as with other plots

# showfliers = False    - remove outliers from plot (points outside of whiskers)

# whis = 2.0            - adjust length of whiskers (default is 1.5 IQR)

# whis = [20, 80]       - specify which percentiles to show as whiskers (boxes show 25th and 75th)

# whis = [0, 100]       - show min and max values as whiskers (instead of IQR)


## Point Plot - shows meanof a variable for each category, with a line to show the CI (bar plot with points instead of bars) 

sns.catplot(x = 'column_name', y = 'column_name', data = data_frame_name, kind = "point")    # specify kind = "point" for point plot


# linestyle = "none"        - remove line between points

# estimator = np.median     - use median instead of mean for summary stat (must first import numpy as np, or from numpy import median)

# capsize = 0.3             - add caps to end of error bars (specify size of caps)

# errorbar = None           - remove error bars from plot

# %%
### Customizations ###


## Style and colour options 

sns.set_style("whitegrid")    # set style of plot (background colour and grid lines)

# "white" (default)
# "dark"
# "whitegrid"
# "darkgrid"
# "ticks"


sns.set_pallette("pastel")    # set colour palette for plot elements

# "RdBu"  or  "RdBu_r"    - red to blue diverging palette (r for reverse)
# "PRGn"  or  "PRGn_r"    - purple to green diverging palette (r for reverse)

# "Greys"
# "Blues"
# "Greens"
# "Reds"
# "Purples"
# "PuRd"
# "GnBu"

custom = ['colour1', 'colour2', 'colour3']    # create custom palette with list of colours (can use hex codes)


sns.set_context("notebook", font_scale = 1.5)    # set context for plot (size of elements)

# "paper" (default)- smaller elements, good for printing
# "notebook"  - medium elements, good for viewing in Jupyter notebooks
# "talk" - larger elements, good for presentations
# "poster" - largest elements, good for posters


## Titles and Labels


# FacetGrid - 1+ plots in a grid (replot and catplot)
# AxesSubplot - single plot(scatterplot, countplot, etc.)
# type(plot_name) - check the plot type


#  Titles - FacetGrid
plot_name = sns.catplot(x = 'column_name', y = 'column_name', data = data_frame_name, kind = "box")    # assign plot to variable name to customize

plot_name.figure.suptitle("Title of Plot", y = 1.5)    # add title to plot, use y = value to adjust position of title (default is 1, 1.5 isa little above)


# Titles and subsitites with AxesSubplot
plot_name.set_title("Title of Plot")  # title for whole figure

plot_name.set_titles("Title of Subplot")    # title for each subplot (only works with subplots)


# Axis Labels
plot_name.set(xlabel = "X Axis Label", ylabel = "Y Axis Label") 


# Rotate tick labels
plt.xticks(rotation = 90)    # rotate x axis tick labels 90 degrees (can adjust angle as needed)

plt.yticks(rotation = 90)    # rotate y axis tick labels 90 degrees (can adjust angle as needed)

# %%
##### END OF VISUALIZATION NOTES #####
